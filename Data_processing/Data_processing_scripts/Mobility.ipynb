# %%
import numpy
import pandas
import math

# %%
stops = pandas.read_csv('stop_withBG1.csv')

# %%
stops.head()
# Out:
#       Unnamed: 0  stop_id  stop_code                       stop_name  \
# 2170        2170    38700        NaN       30th Ave NE & NE 135th St
# 2171        2171    38710        NaN       30th Ave NE & NE 137th St
# 6479        6479    76680        NaN  Lake City Way NE & NE 137th St
# 6485        6485    76750        NaN  Lake City Way NE & NE 137th St
#
#       stop_desc   stop_lat    stop_lon  zone_id  stop_url  location_type  \
# 2170        NaN  47.726749 -122.296303       21       NaN              0
# 2171        NaN  47.728016 -122.296333       21       NaN              0
# 6479        NaN  47.728077 -122.292343       21       NaN              0
# 6485        NaN  47.728016 -122.292137        1       NaN              0
#
#       parent_station        stop_timezone      BG_geoid        BG_label
# 2170             NaN  America/Los_Angeles  5.303300e+11  Blkgrp 0001002
# 2171             NaN  America/Los_Angeles  5.303300e+11  Blkgrp 0001002
# ...

# %%
#stop_id is unique in stops file
BG_data = stops.groupby('BG_label').size().to_frame('number of stops').reset_index()

# %%
BG_data.head()
# Out:
#          BG_label  number of stops
# 0  Blkgrp 0001002                4
# 1  Blkgrp 0001003                4
# 2  Blkgrp 0001004                4
# 3  Blkgrp 0001005                7
# 4  Blkgrp 0002001                7

# %%
stop_times = pandas.read_csv('stop_times.csv')

# %%
stop_times.head()
# Out:
#     trip_id arrival_time departure_time  stop_id  stop_sequence stop_headsign  \
# 0  18164700     08:55:00       08:55:00     6071              2           NaN
# 1  18164700     08:58:01       08:58:01    37100             43           NaN
# 2  18164700     08:58:20       08:58:20    37110             45           NaN
# 3  18164700     08:58:39       08:58:39    37120             47           NaN
# 4  18164700     08:58:55       08:58:55    37130             49           NaN
#
#    pickup_type  drop_off_type  shape_dist_traveled
# 0            0              0                  0.0
# 1            0              0               4433.4
# 2            0              0               4900.6
# 3            0              0               5364.8
# 4            0              0               5754.1

# %%
routes = pandas.read_csv('routes.txt')

# %%
routes.head()
# Out:
#    route_id agency_id route_short_name  route_long_name  \
# 0    100001       KCM                1              NaN
# 1    100002       KCM               10              NaN
# 2    100003       KCM              101              NaN
# 3    100004       KCM              105              NaN
# 4    100005       KCM              106              NaN
#
#                         route_desc  route_type  \
# 0       Kinnear - Downtown Seattle           3
# 1  Capitol Hill - Downtown Seattle           3
# 2    Renton TC to Downtown Seattle           3
# 3       Renton Highlands to Renton           3
# 4      Renton/Skyway/MLK/Intl Dist           3
#
#                                            route_url  route_color  \
# 0  http://metro.kingcounty.gov/schedules/001/n0.html          NaN
# 1  http://metro.kingcounty.gov/schedules/010/n0.html          NaN
# 2  http://metro.kingcounty.gov/schedules/101/n0.html          NaN
# 3  http://metro.kingcounty.gov/schedules/105/n0.html          NaN
# ...

# %%
trips = pandas.read_csv('trips.txt')
trips.head()
# Out:
#    route_id  service_id   trip_id     trip_headsign trip_short_name  \
# 0    100481       14641  18164700             Alki            LOCAL
# 1    100481       14641  18164701             Alki            LOCAL
# 2    100481       14641  18164702  Seacrest Marina            LOCAL
# 3    100481       14641  18164703  Seacrest Marina            LOCAL
# 4    100481       14641  18164704  Seacrest Marina            LOCAL
#
#    direction_id  block_id  shape_id  peak_flag  fare_id
# 0             0   4511901  11775001          0    100.0
# 1             0   4511903  11775001          0    100.0
# 2             1   4511903  20775002          0    100.0
# 3             1   4511901  20775002          0    100.0
# 4             1   4511903  20775002          0    100.0

# %%
#how many times a stop_id appears in the stop_times file is the number of trip ids associated with that stop
result = stop_times.groupby('stop_id').size().to_frame('number of trips').reset_index()
result.head()
# Out:
#    stop_id  number of trips
# 0       20               93
# 1       60               99
# 2       90              316
# 3      110               99
# 4      150              313

# %%
#get the number of trips for each BG
#join stop_id result with stops file (containing the BG labels)
total = result.set_index('stop_id').join(stops.set_index('stop_id'))

# %%
total.head()
# Out:
#          number of trips  Unnamed: 0  stop_code               stop_name  \
# stop_id
# 20                    93         767        NaN     1st Ave & Lenora St
# 60                    99        4199        NaN      1st Ave & Union St
# 90                   316        7511        NaN     1st Ave & Marion St
# 110                   99          98        NaN  1st Ave S & Yesler Way
# 150                  313         394        NaN    1st Ave & Yesler Way
#
#          stop_desc   stop_lat    stop_lon  zone_id  stop_url  location_type  \
# stop_id
# 20             NaN  47.611629 -122.343719       21       NaN              0
# 60             NaN  47.607330 -122.338760       21       NaN              0
# 90             NaN  47.603710 -122.335457       21       NaN              0
# 110            NaN  47.601391 -122.334282       21       NaN              0
# 150            NaN  47.602207 -122.334076       21       NaN              0
#
# ...

# %%
num_trips = total.groupby('BG_label').sum()['number of trips']

# %%
num_trips.head()
# Out:
# BG_label
# Blkgrp 0001002     875
# Blkgrp 0001003    1384
# Blkgrp 0001004     660
# Blkgrp 0001005    2474
# Blkgrp 0002001    1446
# Name: number of trips, dtype: int64

# %%
fares = pandas.read_csv('fare_attributes.txt')
fares.head()
# Out:
#    fare_id agency_id  fare_period_id  price        descriptions currency_type  \
# 0      100       KCM               1   0.00    KCM Regular Free           USD
# 1      101       KCM               1   2.50  KCM Regular 1 Zone           USD
# 2      102       KCM               1   2.50  KCM Regular 2 Zone           USD
# 3      110       KCM               2   2.75     KCM Peak 1 Zone           USD
# 4      112       KCM               2   3.25     KCM Peak 2 Zone           USD
#
#    payment_method  transfers  transfer_duration
# 0               0        NaN               5400
# 1               0        NaN               5400
# 2               0        NaN               5400
# 3               0        NaN               5400
# 4               0        NaN               5400

# %%
fares_rules = pandas.read_csv('fare_rules.txt')
fares_rules.head()
# Out:
#    fare_id  route_id  origin_id  destination_id  contains_id
# 0      101  100001.0        NaN             NaN          NaN
# 1      110  100001.0        NaN             NaN          NaN
# 2      101  100002.0        NaN             NaN          NaN
# 3      110  100002.0        NaN             NaN          NaN
# 4      102  100003.0        NaN             NaN          NaN

# %%
BG_data.to_csv('BG_num_stops.csv')

# %%
num_trips.to_csv('BG_num_trips.csv')

# %%
#################################################################
#travel time to LR station
import googlemaps
from datetime import datetime
gmaps = googlemaps.Client(key='AIzaSyAIDMGHegx6uKnI8chHLBvncQh8MsGwjec')

# %%
###############################################################################
#input: long, lats as strings
#output: journy time in seconds

def get_travel_time(long1,lat1,long2,lat2):
    address1 = str(lat1) + ', ' + str(long1)
    address2 = str(lat2) + ', ' + str(long2)
    
    #print(address1, address2)
    
    now = datetime.now()
    directions_result = gmaps.distance_matrix(address1,
                                     address2,
                                     mode="transit", #walking, transit
                                     departure_time=now)
    
    #print(directions_result)
    
    time_s = directions_result['rows'][0]['elements'][0]['duration']['value']
    
    return time_s

# %%
def get_fastest_travel_time(long1,lat1,inputs):
    time = 100000000000
    
    #find the closest point (straight distance)
    for index, row in inputs.iterrows():
        long2 = float(row['long'])
        lat2 = float(row['lat'])
        time_test = float(get_travel_time(long1,lat1,long2,lat2))
        if time_test < time:
            time = time_test
        
    #use the losest point to calculate the shortest walking distance
    walking_time = float(time)/60
            
    return walking_time

# %%
#get the inputs - in this case the light rail stations
inputs = pandas.read_csv('LightRail.csv')[['long','lat']]

# %%
BG_centroids = pandas.read_csv('BG_centroids.csv')
BG_centroids['time'] = 0

# %%
for index, row in BG_centroids.iloc[393:].iterrows():
    long1 = str(row['long'])
    lat1 = str(row['lat'])
    #print(long1,lat1)
    travel_time = get_fastest_travel_time(long1,lat1,inputs)
    BG_centroids.set_value(index, 'time', travel_time)
# Out:
# {'destination_addresses': ['3712-3728 Montlake Blvd NE, Seattle, WA 98105, USA'], 'origin_addresses': ['5309 28th Ave S, Seattle, WA 98108, USA'], 'rows': [{'elements': [{'distance': {'text': '15.0 km', 'value': 15033}, 'duration': {'text': '41 mins', 'value': 2440}, 'fare': {'currency': 'USD', 'text': '$2.50', 'value': 2.5}, 'status': 'OK'}]}], 'status': 'OK'}
# {'destination_addresses': ['1249A E John St, Seattle, WA 98102, USA'], 'origin_addresses': ['5309 28th Ave S, Seattle, WA 98108, USA'], 'rows': [{'elements': [{'distance': {'text': '11.4 km', 'value': 11413}, 'duration': {'text': '36 mins', 'value': 2180}, 'fare': {'currency': 'USD', 'text': '$2.50', 'value': 2.5}, 'status': 'OK'}]}], 'status': 'OK'}
# ...

# %%
BG_centroids.head()
# Out:
#          gis_id        long        lat  time
# 0  530330001001 -122.284690  47.726825    40
# 1  530330001002 -122.292467  47.729319    23
# 2  530330001003 -122.289454  47.722812    25
# 3  530330001004 -122.294451  47.731938    26
# 4  530330001005 -122.294437  47.722929    21

# %%
BG_centroids.to_csv('BG_trans_LR.csv')

# %%
##do we have street car or other type info avialable?
#route_type = routes.groupby('route_type').size()['types']
route_type = routes.groupby('route_type').size().to_frame('types').reset_index()

# %%
route_type.head()
# Out:
#    route_type  types
# 0           0      3
# 1           3    217
# 2           4      2

# %%
#0 = street car / light rail... does not differentiate these
#3 = bus
#4 = ferry

# %%
#############################################################
#sidewalks
sidewalks = pandas.read_csv('SDOT_Sidewalks.csv')
sidewalks.head()
# Out:
#    OBJECTID  COMPKEY  COMPTYPE  SEGKEY  DISTANCE  ENDDISTANCE  WIDTH  \
# 0         1   290675        97    4803        13        645.0  -20.5
# 1         2   290684        97    4823        13        592.0  -20.5
# 2         3   290404        97    4032        13        376.0  -20.5
# 3         4   290413        97    4027        13        318.0  -20.5
# 4         5   290696        97    4870        13       1345.0  -20.5
#
#       UNITID UNITTYPE                                           UNITDESC  \
# 0   SDW-1519      SDW  31ST AVE NE BETWEEN NE 110TH ST AND NE 113TH S...
# 1  SDW-37919      SDW  31ST AVE NW BETWEEN NW 95TH ST AND NW GOLDEN D...
# 2   SDW-1363      SDW  27TH AVE NE BETWEEN NE 108TH PL AND NE 110TH S...
# 3   SDW-1371      SDW  27TH AVE NE BETWEEN NE 95TH ST AND NE 96TH ST,...
# 4   SDW-1816      SDW  31ST AVE SW BETWEEN SW HOLLY ST AND SW MYRTLE ...
#
#        ...                                          Shape PRIMARYDISTRICTCD  \
# ...

# %%
sidewalks = sidewalks.assign(BG_geoid = 'Nan')
sidewalks = sidewalks.assign(BG_label = 'Nan')

# %%
from shapely.geometry import shape, Point
import json
with open('BG.geojson') as f:
    js = json.load(f)

# %%
#for every sidewalk data point (row in sidewalks), find which BG it is in (according to shape) 
#saved to file -- do not rerun ! 

count = 0
for ind, row in sidewalks.iterrows():
    if row.isnull()['Shape']:
        continue
    parse = row['Shape'].split(', ')
    lat = parse[0][1:]
    long = parse[1][:-1]
    #print(lat,long)
    point = Point(float(long), float(lat))
    for feature in js['features']:
        #print(feature)
        polygon = shape(feature['geometry'])
        #print(polygon.contains(point))
        if polygon.contains(point):
            count = count + 1
            found_polygon = feature['properties']
            #print(polygon['geoid'], polygon['name'])
            sidewalks.loc[ind, 'BG_geoid'] = found_polygon['GEO_ID_GRP']
            sidewalks.loc[ind, 'BG_label'] = found_polygon['BLKGRP_LBL']
            #print('Found containing polygon:', feature['properties'])
            break

# %%
ind
# Out:
# 46140

# %%
sidewalks.head()
# Out:
#    OBJECTID  COMPKEY  COMPTYPE  SEGKEY  DISTANCE  ENDDISTANCE  WIDTH  \
# 0         1   290675        97    4803        13        645.0  -20.5
# 1         2   290684        97    4823        13        592.0  -20.5
# 2         3   290404        97    4032        13        376.0  -20.5
# 3         4   290413        97    4027        13        318.0  -20.5
# 4         5   290696        97    4870        13       1345.0  -20.5
#
#       UNITID UNITTYPE                                           UNITDESC  \
# 0   SDW-1519      SDW  31ST AVE NE BETWEEN NE 110TH ST AND NE 113TH S...
# 1  SDW-37919      SDW  31ST AVE NW BETWEEN NW 95TH ST AND NW GOLDEN D...
# 2   SDW-1363      SDW  27TH AVE NE BETWEEN NE 108TH PL AND NE 110TH S...
# 3   SDW-1371      SDW  27TH AVE NE BETWEEN NE 95TH ST AND NE 96TH ST,...
# 4   SDW-1816      SDW  31ST AVE SW BETWEEN SW HOLLY ST AND SW MYRTLE ...
#
#         ...       SECONDARYDISTRICTCD OVERRIDEYN OVERRIDECOMMENT CURBRAMPHIGH  \
# ...

# %%
sidewalks.isnull().sum()
# Out:
# OBJECTID                          0
# COMPKEY                           0
# COMPTYPE                          0
# SEGKEY                            0
# DISTANCE                          0
# ENDDISTANCE                       3
# WIDTH                           115
# UNITID                            0
# UNITTYPE                          0
# UNITDESC                          0
# ADDBY                             0
# ADDDTTM                           0
# ASBLT                         45249
# CONDITION                         0
# CONDITION_ASSESSMENT_DATE     35241
# CURBTYPE                          0
# CURRENT_STATUS                    0
# CURRENT_STATUS_DATE           10880
# FILLERTYPE                        0
# FILLERWID                         3
# INSTALL_DATE                  45357
# HANSEN_RPT_MVW_GIS_SDW_LEN    46141
# LENUOM                            3
# SW_WIDTH                          3
# MAINTAINED_BY                     0
# MATL                              0
# ...

# %%
sidewalks.to_csv('sidewalks_withBG.csv')

# %%
total_len = sidewalks.groupby('BG_geoid').sum()['Shape_Length']

# %%
total_len.head()
# Out:
# BG_geoid
# 530330001001    46727.071524
# 530330001002    21641.607102
# 530330001003    19761.946021
# 530330001004     7234.775252
# 530330001005    15768.285211
# Name: Shape_Length, dtype: float64

# %%
total_len.to_csv('BG_totalSW.csv')

# %%
result = sidewalks.groupby(['BG_geoid','SRTS_SIDEWALK_RANK']).sum()['Shape_Length']
result.head()
# Out:
# BG_geoid      SRTS_SIDEWALK_RANK
# 530330001001  1.0                     443.427187
#               2.0                   45936.846970
#               3.0                     346.797367
# 530330001002  1.0                    2055.346367
#               2.0                   12882.445284
# Name: Shape_Length, dtype: float64

# %%
#BG sidewalk length where type/rank = #
result1 = sidewalks.loc[sidewalks['SRTS_SIDEWALK_RANK'] == 4.0]
result11 = result1.groupby(['BG_geoid']).sum()['Shape_Length']
result11.head()
# Out:
# BG_geoid
# 530330001002    1477.200989
# 530330001004     596.997731
# 530330001005    1195.269996
# 530330002001     208.236029
# 530330002002     598.412453
# Name: Shape_Length, dtype: float64

# %%
result11.to_csv('BG_SW4.csv')
